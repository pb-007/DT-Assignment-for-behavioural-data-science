# %% [markdown]
# Week 1

# %%
import pandas as pd
import seaborn as sns
df = pd.read_excel('/content/performance_scoreboard_week1.xlsx')
df
# Out:
#      Name  contribution  Initiative  Bottleneck analysis  happiness card  \
# 0    Neha             8           9                    9            7.16
# 1    Amit             8           8                    7            9.16
# 2  Sachin             8           8                    7            8.50
#
#    efforts  significance of efforts score  learn skills  \
# 0       10                             10             9
# 1        8                              8             7
# 2        6                              8             4
#
#    significance of learn skills score  cross functional skillset  \
# 0                                   9                          9
# 1                                   8                          8
# 2                                   8                          7
#
#    efforts to improve conversational and emotional intelligence  \
# 0                                                  9
# 1                                                  8
# ...

# %%
import matplotlib.pyplot as plt
plt.bar(df['Name'], df['Initiative'])
# Out:
# <BarContainer object of 3 artists>

# %%
plt.plot(df['Name'], df['Initiative'])

# %%
corr_matrix = df.corr()
sns.heatmap(corr_matrix, annot=True)
plt.title('Correlation Matrix Heatmap')
plt.show()
# Out:
# <ipython-input-12-30d8cb1e0fca>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df.corr()

# %%
sns.pairplot(df)

# %%
plt.bar(df['Name'], df['happiness card'])
# Out:
# <BarContainer object of 3 artists>

# %%
plt.pie(df['Initiative'], labels = df['Name'], autopct = '%1.1f%%')
plt.title('Initiative Score')
plt.show()

# %%
plt.pie(df['learn skills'], labels = df['Name'], autopct = '%1.1f%%')
plt.title('Skill learning score')
plt.show()

# %%
plt.pie(df['efforts to improve conversational and emotional intelligence'], labels = df['Name'], autopct = '%1.1f%%')
plt.title('efforts to improve conversational and emotional intelligence')
plt.show()

# %%
plt.pie(df['cross functional skillset'], labels = df['Name'], autopct = '%1.1f%%')
plt.title('cross functional skillset')
plt.show()

# %%
plt.pie(df['efforts'], labels = df['Name'], autopct = '%1.1f%%')
plt.title('efforts score')
plt.show()

# %%
plt.pie(df['Bottleneck analysis'], labels = df['Name'], autopct = '%1.1f%%')
plt.title('analysis report')
plt.show()

# %%
plt.pie(df['efforts to improve efficiency'], labels = df['Name'], autopct = '%1.1f%%')
plt.title('efforts to improve efficiency')
plt.show()

# %%
plt.pie(df['happiness card'], labels = df['Name'], autopct = '%1.1f%%')
plt.title('happiness report')
plt.show()

# %% [markdown]
# From the above analysis and visualization, most efforts and skills learning, emotional and conversational skills all are topped by Neha but she is the most unhappy person as compared to sachin and amit.

# %% [markdown]
# Week 2

# %%
df1 = pd.read_excel('/content/performance_scoreboard_week2.xlsx')
df1
# Out:
#      Name  contribution  Initiative  Bottleneck analysis  happiness card
# 0    Neha             9           9                    5            7.16
# 1    Amit             8           8                    6            8.00
# 2  Sachin             7           7                    6            9.34

# %%
plt.pie(df1['contribution'], labels = df1['Name'], autopct = '%1.1f%%')
plt.title('Contribution report')
plt.show()

# %%
plt.pie(df1['Initiative'], labels = df1['Name'], autopct = '%1.1f%%')
plt.title('Initiative report')
plt.show()

# %%
plt.pie(df1['Bottleneck analysis'], labels = df1['Name'], autopct = '%1.1f%%')
plt.title('Bottleneck analysis report')
plt.show()

# %%
plt.pie(df1['happiness card'], labels = df1['Name'], autopct = '%1.1f%%')
plt.title('happiness report')
plt.show()

# %% [markdown]
# Week 3

# %%
df2 = pd.read_excel('/content/performance_scoreboard_week3.xlsx')
df2
# Out:
#      Name  Initiative  contribution  Bottleneck analysis  Unnamed: 4  \
# 0    Neha           8             9                    8         NaN
# 1    Amit           7             8                    6         NaN
# 2  Sachin           7             8                    6         NaN
#
#    Happiness card  preplanned work
# 0             8.5             0.75
# 1             9.0             1.00
# 2             9.0             0.50

# %%
plt.pie(df2['contribution'], labels = df2['Name'], autopct = '%1.1f%%')
plt.title('Contribution report')
plt.show()

# %%
plt.pie(df2['Initiative'], labels = df2['Name'], autopct = '%1.1f%%')
plt.title('Initiative report')
plt.show()

# %%
plt.pie(df2['Bottleneck analysis'], labels = df2['Name'], autopct = '%1.1f%%')
plt.title('Bottleneck analysis report')
plt.show()

# %%
plt.pie(df2['Happiness card'], labels = df2['Name'], autopct = '%1.1f%%')
plt.title('Happiness report')
plt.show()

# %%
plt.pie(df2['preplanned work'], labels = df2['Name'], autopct = '%1.1f%%')
plt.title('preplanned work percentage')
plt.show()
